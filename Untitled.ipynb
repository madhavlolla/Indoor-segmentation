# %%
# !conda list
# Out:
# # packages in environment at /home/madhav/miniconda3/envs/bci_py38:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# absl-py                   2.1.0              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.9.5            py38h01eb140_0    conda-forge
# aiosignal                 1.3.1              pyhd8ed1ab_0    conda-forge
# aiosqlite                 0.19.0             pyhd8ed1ab_0    conda-forge
# alsa-lib                  1.2.12               h4ab18f5_0    conda-forge
# anyio                     4.4.0              pyhd8ed1ab_0    conda-forge
# aom                       3.7.1                h59595ed_0    conda-forge
# argon2-cffi               23.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py38h01eb140_4    conda-forge
# ...
